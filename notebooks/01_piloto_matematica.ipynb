# %% [markdown]
# # Piloto de Matemática — auditoria complementar
# A execução oficial ocorre por `python executar_sprint_01.py`. Este notebook fica reservado para inspeções manuais dos produtos gerados.
